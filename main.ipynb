# %%
from train import train, test
# Out:
# Device: cuda | Device Name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
# Train Model with 25 Epoch

train()
# Out:
# Epoch [1/10]
# Train Loss:  2.8221 | Train Accuracy:  0.0721
# Validation Loss: 2.7813 | Validation Accuracy: 0.0469
# Epoch [2/10]
# Train Loss:  2.7476 | Train Accuracy:  0.1335
# Validation Loss: 2.6839 | Validation Accuracy: 0.2500
# Epoch [3/10]
# Train Loss:  2.6831 | Train Accuracy:  0.1910
# Validation Loss: 2.6385 | Validation Accuracy: 0.2370
# Epoch [4/10]
# Train Loss:  2.6282 | Train Accuracy:  0.2606
# Validation Loss: 2.6090 | Validation Accuracy: 0.3333
# Epoch [5/10]
# Train Loss:  2.5574 | Train Accuracy:  0.3576
# Validation Loss: 2.5247 | Validation Accuracy: 0.4505
# Epoch [6/10]
# Train Loss:  2.5154 | Train Accuracy:  0.3783
# Validation Loss: 2.4574 | Validation Accuracy: 0.6016
# Epoch [7/10]
# Train Loss:  2.4502 | Train Accuracy:  0.4447
# Validation Loss: 2.3990 | Validation Accuracy: 0.5417
# Epoch [8/10]
# Train Loss:  2.3970 | Train Accuracy:  0.4927
# Validation Loss: 2.3505 | Validation Accuracy: 0.6771
# Epoch [9/10]
# ...

# %%
test()
# Out:
# Test Loss: 1.5869, Test Accuracy: 85.91%
